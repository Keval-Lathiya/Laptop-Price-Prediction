# %% [markdown]
# # Laptop Price Prediction

# %% [markdown]
# ## Task
#
# Task is to define and train a machine learning model for predicting the price of a laptop (buynow_price column in the dataset) based on its attributes. When testing and comparing models, aim is to to minimize the RMSE measure.

# %% [markdown]
# ## Data Exploration and Processing

# %%
import pandas as pd
import os
import numpy as np

# %%
# read datasets 
train_df = pd.read_json("datasets/Laptop Price Prediction/train_dataset.json", orient="columns")
test_df = pd.read_json("datasets/Laptop Price Prediction/test_dataset.json", orient="columns")
val_df = pd.read_json("datasets/Laptop Price Prediction/val_dataset.json", orient="columns")

df = pd.concat([train_df, val_df, test_df], axis=0)
df.head(10)
# Out:
#          graphic card type                                     communications  \
# 7233    dedicated graphics                  [bluetooth, lan 10/100/1000 mbps]
# 5845    dedicated graphics                [wi-fi, bluetooth, lan 10/100 mbps]
# 10303                 None        [bluetooth, nfc (near field communication)]
# 10423                 None                                               None
# 5897   integrated graphics                                 [wi-fi, bluetooth]
# 4870   integrated graphics                [wi-fi, bluetooth, lan 10/100 mbps]
# 2498    dedicated graphics           [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 6220    dedicated graphics           [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 10594  integrated graphics              [nfc (near field communication), gps]
# 11640  integrated graphics  [wi-fi 802.11 b/g/n/ac, bluetooth, lan 10/100/...
#
#       resolution (px) CPU cores RAM size                  operating system  \
# 7233      1920 x 1080         4    32 gb                       [no system]
# 5845       1366 x 768         4     8 gb                 [windows 10 home]
# 10303     1920 x 1080         2     8 gb                 [windows 10 home]
# 10423            None         2     None                              None
# 5897      2560 x 1440         4     8 gb                 [windows 10 home]
# 4870       1366 x 768         2     8 gb                 [windows 10 home]
# 2498      1920 x 1080         4     8 gb  [windows 8.1 home 64-bit, other]
# 6220      1920 x 1080         4     8 gb                       [no system]
# 10594     1920 x 1080         2     8 gb         [windows 10 professional]
# 11640     1920 x 1080         2     8 gb         [windows 10 professional]
#
#       drive type                                      input devices  \
# 7233   ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 5845         ssd             [keyboard, touchpad, numeric keyboard]
# 10303        hdd                                               None
# 10423       None                                               None
# 5897         ssd         [keyboard, touchpad, illuminated keyboard]
# 4870         hdd             [keyboard, touchpad, numeric keyboard]
# 2498         hdd  [keyboard, touchpad, illuminated keyboard, num...
# 6220         ssd  [keyboard, touchpad, illuminated keyboard, num...
# 10594       None                                         [touchpad]
# 11640        ssd             [keyboard, touchpad, numeric keyboard]
#
#                                            multimedia RAM type  \
# 7233   [SD card reader, camera, speakers, microphone]     ddr4
# 5845   [SD card reader, camera, speakers, microphone]     ddr3
# 10303                                [SD card reader]     ddr4
# 10423                                            None     None
# 5897   [SD card reader, camera, speakers, microphone]     ddr4
# 4870   [SD card reader, camera, speakers, microphone]     ddr4
# 2498   [SD card reader, camera, speakers, microphone]     ddr3
# 6220   [SD card reader, camera, speakers, microphone]     ddr4
# 10594                                [SD card reader]     ddr4
# 11640  [SD card reader, camera, speakers, microphone]     ddr4
#
#        CPU clock speed (GHz)      CPU model state  drive memory size (GB)  \
# 7233                     2.6  intel core i7   new                  1250.0
# 5845                     2.4  intel core i7   new                   256.0
# 10303                    1.6  intel core i7   new                  1000.0
# 10423                    NaN           None   new                     NaN
# 5897                     1.2      other CPU   new                   256.0
# 4870                     2.0  intel core i3   new                  1000.0
# 2498                     2.4  intel core i7   new                  1000.0
# 6220                     2.5  intel core i5   new                   256.0
# 10594                    2.5  intel core i5   new                   500.0
# 11640                    2.5  intel core i5   new                   256.0
#
#                 warranty  screen size  buynow_price
# 7233   producer warranty  17" - 17.9"        4999.0
# 5845     seller warranty  15" - 15.9"        2649.0
# 10303  producer warranty  15" - 15.9"        3399.0
# 10423  producer warranty         None        1599.0
# 5897   producer warranty  12" - 12.9"        4499.0
# 4870   producer warranty  15" - 15.9"        2099.0
# 2498   producer warranty  17" - 17.9"        2699.0
# 6220   producer warranty  15" - 15.9"        3199.0
# 10594  producer warranty  15" - 15.9"        2749.0
# 11640  producer warranty  15" - 15.9"        3199.0

# %%
df.dtypes
# Out:
# graphic card type          object
# communications             object
# resolution (px)            object
# CPU cores                  object
# RAM size                   object
# operating system           object
# drive type                 object
# input devices              object
# multimedia                 object
# RAM type                   object
# CPU clock speed (GHz)     float64
# CPU model                  object
# state                      object
# drive memory size (GB)    float64
# warranty                   object
# screen size                object
# buynow_price              float64
# dtype: object

# %%
df.shape
# Out:
# (7853, 17)

# %%
# Look at unique values of each column, except the ones formatted as list
for col in df.columns.to_list():
    if type(df[col][0]) != list:
        print(f"unique values of {col} are: ", df[col].unique())
        print("-----------------------------------------------------")
# Out:
# unique values of graphic card type are:  ['dedicated graphics' None 'integrated graphics']
# -----------------------------------------------------
# unique values of resolution (px) are:  ['1920 x 1080' '1366 x 768' None '2560 x 1440' '1600 x 900' '3840 x 2160'
#  'other' '1920 x 1280' '1280 x 800' '3200 x 1800' '2880 x 1620'
#  '2160 x 1440' '1920 x 1200' '2560 x 1600']
# -----------------------------------------------------
# unique values of CPU cores are:  ['4' '2' 'not applicable' '3' '1' '8' '6']
# -----------------------------------------------------
# unique values of RAM size are:  ['32 gb' '8 gb' None '12 gb' '4 gb' '16 gb' '2 gb' '20 gb' '6 gb' '64 gb'
#  '256 mb' '24 gb']
# -----------------------------------------------------
# unique values of drive type are:  ['ssd + hdd' 'ssd' 'hdd' None 'emmc' 'hybrid']
# -----------------------------------------------------
# unique values of RAM type are:  ['ddr4' 'ddr3' None 'ddr3l']
# -----------------------------------------------------
# unique values of CPU clock speed (GHz) are:  [2.6  2.4  1.6   nan 1.2  2.   2.5  2.8  1.9  1.1  2.3  2.24 1.8  3.
#  1.7  2.1  2.7  1.33 2.2  3.9  2.16 2.9  1.83 0.9  1.   1.44 1.58 1.35
#  3.1  0.8  3.5  1.3  1.5  1.86 3.3  1.15 1.68 1.4  2.66 2.13 1.66 1.46
#  2.56 3.8  3.6  0.  ]
# -----------------------------------------------------
# unique values of CPU model are:  ['intel core i7' None 'other CPU' 'intel core i3' 'intel core i5'
#  'intel celeron dual-core' 'intel pentium 4' 'intel celeron quad core '
#  'amd a6' 'intel celeron ' 'intel pentium dual-core' 'amd a12' 'amd a8'
#  'intel pentium quad-core ' 'intel core m' 'amd a4' 'intel celeron m'
#  'amd a10' 'amd e1']
# -----------------------------------------------------
# unique values of state are:  ['new']
# -----------------------------------------------------
# unique values of drive memory size (GB) are:  [1.250e+03 2.560e+02 1.000e+03       nan 5.000e+02 1.128e+03 1.240e+03
#  1.200e+02 1.256e+03 4.800e+02 2.500e+02 1.280e+02 2.400e+02 3.200e+01
#  9.600e+02 6.400e+01 1.000e+00 1.120e+03 2.128e+03 6.800e+01 5.120e+02
#  1.512e+03 1.500e+03 2.000e+03 1.628e+03 2.256e+03 1.800e+02 2.512e+03
#  1.024e+03 2.500e+03 1.756e+03 6.280e+02 5.080e+02 1.520e+02 3.200e+02
#  1.012e+03 7.560e+02 1.600e+02 2.480e+03 4.880e+02 8.000e+00 2.048e+03
#  0.000e+00 1.000e+02 1.008e+03 9.900e+02 2.120e+03 2.480e+02 7.500e+02
#  6.080e+02 4.960e+02 2.960e+03 1.920e+02 1.525e+03 3.680e+02 3.840e+02
#  7.400e+02 5.250e+02 1.480e+03 5.160e+02 3.640e+02 2.720e+02 1.280e+03
#  1.728e+03 1.726e+03 5.240e+02 7.680e+02 2.250e+03 1.000e+04 6.000e+01
#  1.275e+03 2.750e+02 9.800e+02]
# -----------------------------------------------------
# unique values of warranty are:  ['producer warranty' 'seller warranty' 'no warranty']
# -----------------------------------------------------
# unique values of screen size are:  ['17" - 17.9"' '15" - 15.9"' None '12" - 12.9"' '14" - 14.9"'
#  '13" - 13.9"' '11.9" and less']
# -----------------------------------------------------
# unique values of buynow_price are:  [4999.   2649.   3399.   ... 2925.36 8678.   4722.  ]
# -----------------------------------------------------

# %%
#  state only takes one value  
# I'm dropping this column since it won't effect the price
df = df.drop(columns=['state'])
df = df.dropna()

# %%
# columns of communications, input_devices and multimedia include multiple values in a cell in list format
# not possible to represent them in numerics in its current format
# split the values of these columns into different columns
compact_cols = ['communications', 'input devices', 'multimedia']

# %%
# use to_list( ) function to split lists into columns
pd.DataFrame(df['communications'].to_list())
# Out:
#               0                     1                     2     3     4     5
# 0     bluetooth  lan 10/100/1000 mbps                  None  None  None  None
# 1         wi-fi             bluetooth       lan 10/100 mbps  None  None  None
# 2         wi-fi             bluetooth                  None  None  None  None
# 3         wi-fi             bluetooth       lan 10/100 mbps  None  None  None
# 4         wi-fi             bluetooth  lan 10/100/1000 mbps  None  None  None
# ...         ...                   ...                   ...   ...   ...   ...
# 6104      wi-fi             bluetooth  lan 10/100/1000 mbps  None  None  None
# 6105  bluetooth       lan 10/100 mbps                  None  None  None  None
# 6106      wi-fi             bluetooth  lan 10/100/1000 mbps  None  None  None
# 6107  bluetooth       lan 10/100 mbps                  None  None  None  None
# 6108  bluetooth       lan 10/100 mbps                  None  None  None  None
#
# [6109 rows x 6 columns]

# %%
# get unique values of each features in our predefined lists 
# and convert them to new feature names

def get_unique_vals(col_name):
    #to_list function splits each comma separated value to a new column   
    col_df = pd.DataFrame(df[col_name].to_list())
    unique_vals = list()
    for col in col_df.columns.to_list():
        unique_vals += [val for val in list(col_df[col].unique()) if (val not in unique_vals and val is not None) ]

    return unique_vals

# %%
compact_dict = {col: [] for  col in compact_cols}

# apply get_unique_vals to all compact_cols
# search through the dataframe and add a feature to unique_vals list when it is not included before
for col in compact_cols:
    compact_dict[col] = get_unique_vals(col)

# %%
compact_dict
# Out:
# {'communications': ['bluetooth',
#   'wi-fi',
#   'wi-fi 802.11 b/g/n/ac',
#   'lan 10/100 mbps',
#   'wi-fi 802.11 a/b/g/n/ac',
#   'nfc (near field communication)',
#   'lan 10/100/1000 mbps',
#   'gps',
#   'wi-fi 802.11 b/g/n',
#   'intel wireless display (widi)',
#   'wi-fi 802.11 a/b/g/n',
#   'modem 3g (wwan)',
#   'modem 4g (lte)'],
#  'input devices': ['keyboard',
#   'touchpad',
#   'illuminated keyboard',
#   'numeric keyboard'],
#  'multimedia': ['SD card reader', 'camera', 'microphone', 'speakers']}

# %%
# transform string value to integer by excluding gb and mb
df['RAM size'] = df['RAM size'].str.replace(' gb','',regex=True)

# when regex=False, replace requires exact match
df['RAM size'] = df['RAM size'].str.replace('256 mb','0.256',regex=False)
df
# Out:
#         graphic card type                            communications  \
# 7233   dedicated graphics         [bluetooth, lan 10/100/1000 mbps]
# 5845   dedicated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 5897  integrated graphics                        [wi-fi, bluetooth]
# 4870  integrated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 2498   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# ...                   ...                                       ...
# 9211   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 2748   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 2072   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 4741   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 6980   dedicated graphics              [bluetooth, lan 10/100 mbps]
#
#      resolution (px) CPU cores RAM size                  operating system  \
# 7233     1920 x 1080         4       32                       [no system]
# 5845      1366 x 768         4        8                 [windows 10 home]
# 5897     2560 x 1440         4        8                 [windows 10 home]
# 4870      1366 x 768         2        8                 [windows 10 home]
# 2498     1920 x 1080         4        8  [windows 8.1 home 64-bit, other]
# ...              ...       ...      ...                               ...
# 9211     1920 x 1080         4       32                 [windows 10 home]
# 2748      1600 x 900         4        8                 [windows 10 home]
# 2072     1920 x 1080         4        8                       [no system]
# 4741     1920 x 1080         4       12                       [no system]
# 6980     1920 x 1080         4       32                 [windows 10 home]
#
#      drive type                                      input devices  \
# 7233  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 5845        ssd             [keyboard, touchpad, numeric keyboard]
# 5897        ssd         [keyboard, touchpad, illuminated keyboard]
# 4870        hdd             [keyboard, touchpad, numeric keyboard]
# 2498        hdd  [keyboard, touchpad, illuminated keyboard, num...
# ...         ...                                                ...
# 9211        ssd  [keyboard, touchpad, illuminated keyboard, num...
# 2748        hdd             [keyboard, touchpad, numeric keyboard]
# 2072  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 4741  ssd + hdd         [keyboard, touchpad, illuminated keyboard]
# 6980        ssd         [keyboard, touchpad, illuminated keyboard]
#
#                                           multimedia RAM type  \
# 7233  [SD card reader, camera, speakers, microphone]     ddr4
# 5845  [SD card reader, camera, speakers, microphone]     ddr3
# 5897  [SD card reader, camera, speakers, microphone]     ddr4
# 4870  [SD card reader, camera, speakers, microphone]     ddr4
# 2498  [SD card reader, camera, speakers, microphone]     ddr3
# ...                                              ...      ...
# 9211  [SD card reader, camera, speakers, microphone]     ddr4
# 2748  [SD card reader, camera, speakers, microphone]     ddr3
# 2072  [SD card reader, camera, speakers, microphone]     ddr4
# 4741  [SD card reader, camera, speakers, microphone]     ddr4
# 6980                  [camera, speakers, microphone]     ddr4
#
#       CPU clock speed (GHz)      CPU model  drive memory size (GB)  \
# 7233                    2.6  intel core i7                  1250.0
# 5845                    2.4  intel core i7                   256.0
# 5897                    1.2      other CPU                   256.0
# 4870                    2.0  intel core i3                  1000.0
# 2498                    2.4  intel core i7                  1000.0
# ...                     ...            ...                     ...
# 9211                    2.8  intel core i7                   500.0
# 2748                    2.2  intel core i7                  1000.0
# 2072                    2.6  intel core i7                  1120.0
# 4741                    2.8  intel core i7                  1256.0
# 6980                    2.8  intel core i7                   240.0
#
#                warranty  screen size  buynow_price
# 7233  producer warranty  17" - 17.9"       4999.00
# 5845    seller warranty  15" - 15.9"       2649.00
# 5897  producer warranty  12" - 12.9"       4499.00
# 4870  producer warranty  15" - 15.9"       2099.00
# 2498  producer warranty  17" - 17.9"       2699.00
# ...                 ...          ...           ...
# 9211  producer warranty  15" - 15.9"       5599.00
# 2748    seller warranty  17" - 17.9"       2925.36
# 2072  producer warranty  17" - 17.9"       3799.00
# 4741  producer warranty  15" - 15.9"       5589.00
# 6980  producer warranty  15" - 15.9"       8678.00
#
# [6109 rows x 16 columns]

# %%
# screen size column is given as intervals. 
# convert it as integers such as so 11.9" and less would become 11
df['screen size'] = df['screen size'].apply(lambda x: int(str(x)[:2]))
df
# Out:
#         graphic card type                            communications  \
# 7233   dedicated graphics         [bluetooth, lan 10/100/1000 mbps]
# 5845   dedicated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 5897  integrated graphics                        [wi-fi, bluetooth]
# 4870  integrated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 2498   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# ...                   ...                                       ...
# 9211   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 2748   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 2072   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 4741   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 6980   dedicated graphics              [bluetooth, lan 10/100 mbps]
#
#      resolution (px) CPU cores RAM size                  operating system  \
# 7233     1920 x 1080         4       32                       [no system]
# 5845      1366 x 768         4        8                 [windows 10 home]
# 5897     2560 x 1440         4        8                 [windows 10 home]
# 4870      1366 x 768         2        8                 [windows 10 home]
# 2498     1920 x 1080         4        8  [windows 8.1 home 64-bit, other]
# ...              ...       ...      ...                               ...
# 9211     1920 x 1080         4       32                 [windows 10 home]
# 2748      1600 x 900         4        8                 [windows 10 home]
# 2072     1920 x 1080         4        8                       [no system]
# 4741     1920 x 1080         4       12                       [no system]
# 6980     1920 x 1080         4       32                 [windows 10 home]
#
#      drive type                                      input devices  \
# 7233  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 5845        ssd             [keyboard, touchpad, numeric keyboard]
# 5897        ssd         [keyboard, touchpad, illuminated keyboard]
# 4870        hdd             [keyboard, touchpad, numeric keyboard]
# 2498        hdd  [keyboard, touchpad, illuminated keyboard, num...
# ...         ...                                                ...
# 9211        ssd  [keyboard, touchpad, illuminated keyboard, num...
# 2748        hdd             [keyboard, touchpad, numeric keyboard]
# 2072  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 4741  ssd + hdd         [keyboard, touchpad, illuminated keyboard]
# 6980        ssd         [keyboard, touchpad, illuminated keyboard]
#
#                                           multimedia RAM type  \
# 7233  [SD card reader, camera, speakers, microphone]     ddr4
# 5845  [SD card reader, camera, speakers, microphone]     ddr3
# 5897  [SD card reader, camera, speakers, microphone]     ddr4
# 4870  [SD card reader, camera, speakers, microphone]     ddr4
# 2498  [SD card reader, camera, speakers, microphone]     ddr3
# ...                                              ...      ...
# 9211  [SD card reader, camera, speakers, microphone]     ddr4
# 2748  [SD card reader, camera, speakers, microphone]     ddr3
# 2072  [SD card reader, camera, speakers, microphone]     ddr4
# 4741  [SD card reader, camera, speakers, microphone]     ddr4
# 6980                  [camera, speakers, microphone]     ddr4
#
#       CPU clock speed (GHz)      CPU model  drive memory size (GB)  \
# 7233                    2.6  intel core i7                  1250.0
# 5845                    2.4  intel core i7                   256.0
# 5897                    1.2      other CPU                   256.0
# 4870                    2.0  intel core i3                  1000.0
# 2498                    2.4  intel core i7                  1000.0
# ...                     ...            ...                     ...
# 9211                    2.8  intel core i7                   500.0
# 2748                    2.2  intel core i7                  1000.0
# 2072                    2.6  intel core i7                  1120.0
# 4741                    2.8  intel core i7                  1256.0
# 6980                    2.8  intel core i7                   240.0
#
#                warranty  screen size  buynow_price
# 7233  producer warranty           17       4999.00
# 5845    seller warranty           15       2649.00
# 5897  producer warranty           12       4499.00
# 4870  producer warranty           15       2099.00
# 2498  producer warranty           17       2699.00
# ...                 ...          ...           ...
# 9211  producer warranty           15       5599.00
# 2748    seller warranty           17       2925.36
# 2072  producer warranty           17       3799.00
# 4741  producer warranty           15       5589.00
# 6980  producer warranty           15       8678.00
#
# [6109 rows x 16 columns]

# %%
# split resolution (px) column into two columns of integers (resolution_x and resolution_y)
# as 1280 x 800 would have 1280 in the first column and 800 in the second column 
df['resolution_x'] = df['resolution (px)'].apply(lambda x: x.split(' x ')[0]).astype(int)
df['resolution_y'] = df['resolution (px)'].apply(lambda x: x.split(' x ')[1]).astype(int)
df
# Out:
#         graphic card type                            communications  \
# 7233   dedicated graphics         [bluetooth, lan 10/100/1000 mbps]
# 5845   dedicated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 5897  integrated graphics                        [wi-fi, bluetooth]
# 4870  integrated graphics       [wi-fi, bluetooth, lan 10/100 mbps]
# 2498   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# ...                   ...                                       ...
# 9211   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 2748   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 2072   dedicated graphics  [wi-fi, bluetooth, lan 10/100/1000 mbps]
# 4741   dedicated graphics              [bluetooth, lan 10/100 mbps]
# 6980   dedicated graphics              [bluetooth, lan 10/100 mbps]
#
#      resolution (px) CPU cores RAM size                  operating system  \
# 7233     1920 x 1080         4       32                       [no system]
# 5845      1366 x 768         4        8                 [windows 10 home]
# 5897     2560 x 1440         4        8                 [windows 10 home]
# 4870      1366 x 768         2        8                 [windows 10 home]
# 2498     1920 x 1080         4        8  [windows 8.1 home 64-bit, other]
# ...              ...       ...      ...                               ...
# 9211     1920 x 1080         4       32                 [windows 10 home]
# 2748      1600 x 900         4        8                 [windows 10 home]
# 2072     1920 x 1080         4        8                       [no system]
# 4741     1920 x 1080         4       12                       [no system]
# 6980     1920 x 1080         4       32                 [windows 10 home]
#
#      drive type                                      input devices  \
# 7233  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 5845        ssd             [keyboard, touchpad, numeric keyboard]
# 5897        ssd         [keyboard, touchpad, illuminated keyboard]
# 4870        hdd             [keyboard, touchpad, numeric keyboard]
# 2498        hdd  [keyboard, touchpad, illuminated keyboard, num...
# ...         ...                                                ...
# 9211        ssd  [keyboard, touchpad, illuminated keyboard, num...
# 2748        hdd             [keyboard, touchpad, numeric keyboard]
# 2072  ssd + hdd  [keyboard, touchpad, illuminated keyboard, num...
# 4741  ssd + hdd         [keyboard, touchpad, illuminated keyboard]
# 6980        ssd         [keyboard, touchpad, illuminated keyboard]
#
#                                           multimedia RAM type  \
# 7233  [SD card reader, camera, speakers, microphone]     ddr4
# 5845  [SD card reader, camera, speakers, microphone]     ddr3
# 5897  [SD card reader, camera, speakers, microphone]     ddr4
# 4870  [SD card reader, camera, speakers, microphone]     ddr4
# 2498  [SD card reader, camera, speakers, microphone]     ddr3
# ...                                              ...      ...
# 9211  [SD card reader, camera, speakers, microphone]     ddr4
# 2748  [SD card reader, camera, speakers, microphone]     ddr3
# 2072  [SD card reader, camera, speakers, microphone]     ddr4
# 4741  [SD card reader, camera, speakers, microphone]     ddr4
# 6980                  [camera, speakers, microphone]     ddr4
#
#       CPU clock speed (GHz)      CPU model  drive memory size (GB)  \
# 7233                    2.6  intel core i7                  1250.0
# 5845                    2.4  intel core i7                   256.0
# 5897                    1.2      other CPU                   256.0
# 4870                    2.0  intel core i3                  1000.0
# 2498                    2.4  intel core i7                  1000.0
# ...                     ...            ...                     ...
# 9211                    2.8  intel core i7                   500.0
# 2748                    2.2  intel core i7                  1000.0
# 2072                    2.6  intel core i7                  1120.0
# 4741                    2.8  intel core i7                  1256.0
# 6980                    2.8  intel core i7                   240.0
#
#                warranty  screen size  buynow_price  resolution_x  resolution_y
# 7233  producer warranty           17       4999.00          1920          1080
# 5845    seller warranty           15       2649.00          1366           768
# 5897  producer warranty           12       4499.00          2560          1440
# 4870  producer warranty           15       2099.00          1366           768
# 2498  producer warranty           17       2699.00          1920          1080
# ...                 ...          ...           ...           ...           ...
# 9211  producer warranty           15       5599.00          1920          1080
# 2748    seller warranty           17       2925.36          1600           900
# 2072  producer warranty           17       3799.00          1920          1080
# 4741  producer warranty           15       5589.00          1920          1080
# 6980  producer warranty           15       8678.00          1920          1080
#
# [6109 rows x 18 columns]

# %%
# resolution (px) is divided into resolution_x and resolution_y 
# drop resolution (px) 
df = df.drop(columns=['resolution (px)'])

# %%
df.dtypes
# Out:
# graphic card type          object
# communications             object
# CPU cores                  object
# RAM size                   object
# operating system           object
# drive type                 object
# input devices              object
# multimedia                 object
# RAM type                   object
# CPU clock speed (GHz)     float64
# CPU model                  object
# drive memory size (GB)    float64
# warranty                   object
# screen size                 int64
# buynow_price              float64
# resolution_x                int32
# resolution_y                int32
# dtype: object

# %%
# put all numerical columns together
numerical_cols = ['CPU cores', 'RAM size', 'CPU clock speed (GHz)','drive memory size (GB)', 'screen size', 'resolution_x', 'resolution_y']
numerical_df = df[numerical_cols].astype(float)
numerical_df
# Out:
#       CPU cores  RAM size  CPU clock speed (GHz)  drive memory size (GB)  \
# 7233        4.0      32.0                    2.6                  1250.0
# 5845        4.0       8.0                    2.4                   256.0
# 5897        4.0       8.0                    1.2                   256.0
# 4870        2.0       8.0                    2.0                  1000.0
# 2498        4.0       8.0                    2.4                  1000.0
# ...         ...       ...                    ...                     ...
# 9211        4.0      32.0                    2.8                   500.0
# 2748        4.0       8.0                    2.2                  1000.0
# 2072        4.0       8.0                    2.6                  1120.0
# 4741        4.0      12.0                    2.8                  1256.0
# 6980        4.0      32.0                    2.8                   240.0
#
#       screen size  resolution_x  resolution_y
# 7233         17.0        1920.0        1080.0
# 5845         15.0        1366.0         768.0
# 5897         12.0        2560.0        1440.0
# 4870         15.0        1366.0         768.0
# 2498         17.0        1920.0        1080.0
# ...           ...           ...           ...
# 9211         15.0        1920.0        1080.0
# 2748         17.0        1600.0         900.0
# 2072         17.0        1920.0        1080.0
# 4741         15.0        1920.0        1080.0
# 6980         15.0        1920.0        1080.0
#
# [6109 rows x 7 columns]

# %%
# use get_dummies( ) from pandas library to convert operating system column as categories
dummies_df = df['operating system'].str.join('|').str.get_dummies()
dummies_df
# Out:
#       no system  other  windows 10 home  windows 10 professional  \
# 7233          1      0                0                        0
# 5845          0      0                1                        0
# 5897          0      0                1                        0
# 4870          0      0                1                        0
# 2498          0      1                0                        0
# ...         ...    ...              ...                      ...
# 9211          0      0                1                        0
# 2748          0      0                1                        0
# 2072          1      0                0                        0
# 4741          1      0                0                        0
# 6980          0      0                1                        0
#
#       windows 7 home 64-bit  windows 7 professional 32-bit  \
# 7233                      0                              0
# 5845                      0                              0
# 5897                      0                              0
# 4870                      0                              0
# 2498                      0                              0
# ...                     ...                            ...
# 9211                      0                              0
# 2748                      0                              0
# 2072                      0                              0
# 4741                      0                              0
# 6980                      0                              0
#
#       windows 7 professional 64-bit  windows 8.1 home 32-bit  \
# 7233                              0                        0
# 5845                              0                        0
# 5897                              0                        0
# 4870                              0                        0
# 2498                              0                        0
# ...                             ...                      ...
# 9211                              0                        0
# 2748                              0                        0
# 2072                              0                        0
# 4741                              0                        0
# 6980                              0                        0
#
#       windows 8.1 home 64-bit  windows 8.1 professional 32-bit  \
# 7233                        0                                0
# 5845                        0                                0
# 5897                        0                                0
# 4870                        0                                0
# 2498                        1                                0
# ...                       ...                              ...
# 9211                        0                                0
# 2748                        0                                0
# 2072                        0                                0
# 4741                        0                                0
# 6980                        0                                0
#
#       windows 8.1 professional 64-bit
# 7233                                0
# 5845                                0
# 5897                                0
# 4870                                0
# 2498                                0
# ...                               ...
# 9211                                0
# 2748                                0
# 2072                                0
# 4741                                0
# 6980                                0
#
# [6109 rows x 11 columns]

# %%
# apply same logic to other suitable variables
dummy_cols = ['drive type', 'RAM type', 'CPU model']
for col in dummy_cols:
    col_dummies_df = df[col].str.get_dummies()
    dummies_df = pd.concat([dummies_df, col_dummies_df], axis=1)
    
dummies_df
# Out:
#       no system  other  windows 10 home  windows 10 professional  \
# 7233          1      0                0                        0
# 5845          0      0                1                        0
# 5897          0      0                1                        0
# 4870          0      0                1                        0
# 2498          0      1                0                        0
# ...         ...    ...              ...                      ...
# 9211          0      0                1                        0
# 2748          0      0                1                        0
# 2072          1      0                0                        0
# 4741          1      0                0                        0
# 6980          0      0                1                        0
#
#       windows 7 home 64-bit  windows 7 professional 32-bit  \
# 7233                      0                              0
# 5845                      0                              0
# 5897                      0                              0
# 4870                      0                              0
# 2498                      0                              0
# ...                     ...                            ...
# 9211                      0                              0
# 2748                      0                              0
# 2072                      0                              0
# 4741                      0                              0
# 6980                      0                              0
#
#       windows 7 professional 64-bit  windows 8.1 home 32-bit  \
# 7233                              0                        0
# 5845                              0                        0
# 5897                              0                        0
# 4870                              0                        0
# 2498                              0                        0
# ...                             ...                      ...
# 9211                              0                        0
# 2748                              0                        0
# 2072                              0                        0
# 4741                              0                        0
# 6980                              0                        0
#
#       windows 8.1 home 64-bit  windows 8.1 professional 32-bit  ...  \
# 7233                        0                                0  ...
# 5845                        0                                0  ...
# 5897                        0                                0  ...
# 4870                        0                                0  ...
# 2498                        1                                0  ...
# ...                       ...                              ...  ...
# 9211                        0                                0  ...
# 2748                        0                                0  ...
# 2072                        0                                0  ...
# 4741                        0                                0  ...
# 6980                        0                                0  ...
#
#       intel celeron dual-core  intel celeron m  intel celeron quad core   \
# 7233                        0                0                         0
# 5845                        0                0                         0
# 5897                        0                0                         0
# 4870                        0                0                         0
# 2498                        0                0                         0
# ...                       ...              ...                       ...
# 9211                        0                0                         0
# 2748                        0                0                         0
# 2072                        0                0                         0
# 4741                        0                0                         0
# 6980                        0                0                         0
#
#       intel core i3  intel core i5  intel core i7  intel core m  \
# 7233              0              0              1             0
# 5845              0              0              1             0
# 5897              0              0              0             0
# 4870              1              0              0             0
# 2498              0              0              1             0
# ...             ...            ...            ...           ...
# 9211              0              0              1             0
# 2748              0              0              1             0
# 2072              0              0              1             0
# 4741              0              0              1             0
# 6980              0              0              1             0
#
#       intel pentium dual-core  intel pentium quad-core   other CPU
# 7233                        0                         0          0
# 5845                        0                         0          0
# 5897                        0                         0          1
# 4870                        0                         0          0
# 2498                        0                         0          0
# ...                       ...                       ...        ...
# 9211                        0                         0          0
# 2748                        0                         0          0
# 2072                        0                         0          0
# 4741                        0                         0          0
# 6980                        0                         0          0
#
# [6109 rows x 36 columns]

# %%
# check remaining columns
label_col = ['buynow_price']
categorical_columns = [col for col in df.columns.to_list() if col not in compact_cols + label_col + numerical_cols + ['operating system'] + dummy_cols]
categorical_columns
# Out:
# ['graphic card type', 'warranty']

# %%
# encode them
categorical_df = pd.get_dummies(df[categorical_columns])
categorical_df
# Out:
#       graphic card type_dedicated graphics  \
# 7233                                  True
# 5845                                  True
# 5897                                 False
# 4870                                 False
# 2498                                  True
# ...                                    ...
# 9211                                  True
# 2748                                  True
# 2072                                  True
# 4741                                  True
# 6980                                  True
#
#       graphic card type_integrated graphics  warranty_producer warranty  \
# 7233                                  False                        True
# 5845                                  False                       False
# 5897                                   True                        True
# 4870                                   True                        True
# 2498                                  False                        True
# ...                                     ...                         ...
# 9211                                  False                        True
# 2748                                  False                       False
# 2072                                  False                        True
# 4741                                  False                        True
# 6980                                  False                        True
#
#       warranty_seller warranty
# 7233                     False
# 5845                      True
# 5897                     False
# 4870                     False
# 2498                     False
# ...                        ...
# 9211                     False
# 2748                      True
# 2072                     False
# 4741                     False
# 6980                     False
#
# [6109 rows x 4 columns]

# %%
# put unique_vals to compact_df columns
unique_cols = list()
for col in compact_cols:
    unique_cols += compact_dict[col]
compact_df = pd.DataFrame(columns = unique_cols , index=df.index, data=np.zeros((df.shape[0], len(unique_cols))))
compact_df
# Out:
#       bluetooth  wi-fi  wi-fi 802.11 b/g/n/ac  lan 10/100 mbps  \
# 7233        0.0    0.0                    0.0              0.0
# 5845        0.0    0.0                    0.0              0.0
# 5897        0.0    0.0                    0.0              0.0
# 4870        0.0    0.0                    0.0              0.0
# 2498        0.0    0.0                    0.0              0.0
# ...         ...    ...                    ...              ...
# 9211        0.0    0.0                    0.0              0.0
# 2748        0.0    0.0                    0.0              0.0
# 2072        0.0    0.0                    0.0              0.0
# 4741        0.0    0.0                    0.0              0.0
# 6980        0.0    0.0                    0.0              0.0
#
#       wi-fi 802.11 a/b/g/n/ac  nfc (near field communication)  \
# 7233                      0.0                             0.0
# 5845                      0.0                             0.0
# 5897                      0.0                             0.0
# 4870                      0.0                             0.0
# 2498                      0.0                             0.0
# ...                       ...                             ...
# 9211                      0.0                             0.0
# 2748                      0.0                             0.0
# 2072                      0.0                             0.0
# 4741                      0.0                             0.0
# 6980                      0.0                             0.0
#
#       lan 10/100/1000 mbps  gps  wi-fi 802.11 b/g/n  \
# 7233                   0.0  0.0                 0.0
# 5845                   0.0  0.0                 0.0
# 5897                   0.0  0.0                 0.0
# 4870                   0.0  0.0                 0.0
# 2498                   0.0  0.0                 0.0
# ...                    ...  ...                 ...
# 9211                   0.0  0.0                 0.0
# 2748                   0.0  0.0                 0.0
# 2072                   0.0  0.0                 0.0
# 4741                   0.0  0.0                 0.0
# 6980                   0.0  0.0                 0.0
#
#       intel wireless display (widi)  ...  modem 3g (wwan)  modem 4g (lte)  \
# 7233                            0.0  ...              0.0             0.0
# 5845                            0.0  ...              0.0             0.0
# 5897                            0.0  ...              0.0             0.0
# 4870                            0.0  ...              0.0             0.0
# 2498                            0.0  ...              0.0             0.0
# ...                             ...  ...              ...             ...
# 9211                            0.0  ...              0.0             0.0
# 2748                            0.0  ...              0.0             0.0
# 2072                            0.0  ...              0.0             0.0
# 4741                            0.0  ...              0.0             0.0
# 6980                            0.0  ...              0.0             0.0
#
#       keyboard  touchpad  illuminated keyboard  numeric keyboard  \
# 7233       0.0       0.0                   0.0               0.0
# 5845       0.0       0.0                   0.0               0.0
# 5897       0.0       0.0                   0.0               0.0
# 4870       0.0       0.0                   0.0               0.0
# 2498       0.0       0.0                   0.0               0.0
# ...        ...       ...                   ...               ...
# 9211       0.0       0.0                   0.0               0.0
# 2748       0.0       0.0                   0.0               0.0
# 2072       0.0       0.0                   0.0               0.0
# 4741       0.0       0.0                   0.0               0.0
# 6980       0.0       0.0                   0.0               0.0
#
#       SD card reader  camera  microphone  speakers
# 7233             0.0     0.0         0.0       0.0
# 5845             0.0     0.0         0.0       0.0
# 5897             0.0     0.0         0.0       0.0
# 4870             0.0     0.0         0.0       0.0
# 2498             0.0     0.0         0.0       0.0
# ...              ...     ...         ...       ...
# 9211             0.0     0.0         0.0       0.0
# 2748             0.0     0.0         0.0       0.0
# 2072             0.0     0.0         0.0       0.0
# 4741             0.0     0.0         0.0       0.0
# 6980             0.0     0.0         0.0       0.0
#
# [6109 rows x 21 columns]

# %%
# get the values of compact_df from original dataframe
# If the computer includes the column name as a feature assign 1, otherwise 0
for col, unique_list in compact_dict.items():
    for unique in unique_list:
        compact_df[unique] = df[col].apply(lambda x: 1 if unique in x else 0)

compact_df
# Out:
#       bluetooth  wi-fi  wi-fi 802.11 b/g/n/ac  lan 10/100 mbps  \
# 7233          1      0                      0                0
# 5845          1      1                      0                1
# 5897          1      1                      0                0
# 4870          1      1                      0                1
# 2498          1      1                      0                0
# ...         ...    ...                    ...              ...
# 9211          1      1                      0                0
# 2748          1      0                      0                1
# 2072          1      1                      0                0
# 4741          1      0                      0                1
# 6980          1      0                      0                1
#
#       wi-fi 802.11 a/b/g/n/ac  nfc (near field communication)  \
# 7233                        0                               0
# 5845                        0                               0
# 5897                        0                               0
# 4870                        0                               0
# 2498                        0                               0
# ...                       ...                             ...
# 9211                        0                               0
# 2748                        0                               0
# 2072                        0                               0
# 4741                        0                               0
# 6980                        0                               0
#
#       lan 10/100/1000 mbps  gps  wi-fi 802.11 b/g/n  \
# 7233                     1    0                   0
# 5845                     0    0                   0
# 5897                     0    0                   0
# 4870                     0    0                   0
# 2498                     1    0                   0
# ...                    ...  ...                 ...
# 9211                     1    0                   0
# 2748                     0    0                   0
# 2072                     1    0                   0
# 4741                     0    0                   0
# 6980                     0    0                   0
#
#       intel wireless display (widi)  ...  modem 3g (wwan)  modem 4g (lte)  \
# 7233                              0  ...                0               0
# 5845                              0  ...                0               0
# 5897                              0  ...                0               0
# 4870                              0  ...                0               0
# 2498                              0  ...                0               0
# ...                             ...  ...              ...             ...
# 9211                              0  ...                0               0
# 2748                              0  ...                0               0
# 2072                              0  ...                0               0
# 4741                              0  ...                0               0
# 6980                              0  ...                0               0
#
#       keyboard  touchpad  illuminated keyboard  numeric keyboard  \
# 7233         1         1                     1                 1
# 5845         1         1                     0                 1
# 5897         1         1                     1                 0
# 4870         1         1                     0                 1
# 2498         1         1                     1                 1
# ...        ...       ...                   ...               ...
# 9211         1         1                     1                 1
# 2748         1         1                     0                 1
# 2072         1         1                     1                 1
# 4741         1         1                     1                 0
# 6980         1         1                     1                 0
#
#       SD card reader  camera  microphone  speakers
# 7233               1       1           1         1
# 5845               1       1           1         1
# 5897               1       1           1         1
# 4870               1       1           1         1
# 2498               1       1           1         1
# ...              ...     ...         ...       ...
# 9211               1       1           1         1
# 2748               1       1           1         1
# 2072               1       1           1         1
# 4741               1       1           1         1
# 6980               0       1           1         1
#
# [6109 rows x 21 columns]

# %%
# concatenate all processed dataframe to put together
new_df = pd.concat([categorical_df, numerical_df, compact_df, dummies_df],axis=1)
new_df.head(5)
# Out:
#       graphic card type_dedicated graphics  \
# 7233                                  True
# 5845                                  True
# 5897                                 False
# 4870                                 False
# 2498                                  True
#
#       graphic card type_integrated graphics  warranty_producer warranty  \
# 7233                                  False                        True
# 5845                                  False                       False
# 5897                                   True                        True
# 4870                                   True                        True
# 2498                                  False                        True
#
#       warranty_seller warranty  CPU cores  RAM size  CPU clock speed (GHz)  \
# 7233                     False        4.0      32.0                    2.6
# 5845                      True        4.0       8.0                    2.4
# 5897                     False        4.0       8.0                    1.2
# 4870                     False        2.0       8.0                    2.0
# 2498                     False        4.0       8.0                    2.4
#
#       drive memory size (GB)  screen size  resolution_x  ...  \
# 7233                  1250.0         17.0        1920.0  ...
# 5845                   256.0         15.0        1366.0  ...
# 5897                   256.0         12.0        2560.0  ...
# 4870                  1000.0         15.0        1366.0  ...
# 2498                  1000.0         17.0        1920.0  ...
#
#       intel celeron dual-core  intel celeron m  intel celeron quad core   \
# 7233                        0                0                         0
# 5845                        0                0                         0
# 5897                        0                0                         0
# 4870                        0                0                         0
# 2498                        0                0                         0
#
#       intel core i3  intel core i5  intel core i7  intel core m  \
# 7233              0              0              1             0
# 5845              0              0              1             0
# 5897              0              0              0             0
# 4870              1              0              0             0
# 2498              0              0              1             0
#
#       intel pentium dual-core  intel pentium quad-core   other CPU
# 7233                        0                         0          0
# 5845                        0                         0          0
# 5897                        0                         0          1
# 4870                        0                         0          0
# 2498                        0                         0          0
#
# [5 rows x 68 columns]

# %% [markdown]
# ## Multicollinearity Check
# Multicollinearity is a potential problem for this regression task. I will check it through Variance Inflation Factor (VIF). I will eliminate all features that have VIF score above 20. For each iteration,  will drop only one feature, since when the feature set is changed VIF scores also change.

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def compute_vif(df, features):
    # only numeric data is processed
    df = df[features].select_dtypes(include=[np.number])

    # Handle missing values 
    df = df.fillna(df.mean())

    vif_data = pd.DataFrame()
    vif_data["feature"] = df.columns
    vif_data["VIF"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
    return vif_data.sort_values(by=['VIF']).reset_index(drop=True)

# Apply VIF computation to all numeric columns
features = new_df.columns.to_list()
vif_data = compute_vif(new_df, features)
# Out:
# C:\Users\keval\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
# drop with highest vif score until all vif scores are under 20
multicollinearity = True

while multicollinearity:
    highest_vif_feature = vif_data['feature'].values.tolist()[-1]
    print("I will remove", highest_vif_feature)
    features.remove(highest_vif_feature)
    vif_data = compute_vif(new_df, features)
    multicollinearity = False if len(vif_data[vif_data.VIF > 20]) == 0 else True

selected_features = vif_data['feature'].values.tolist()
vif_data
# Out:
# I will remove other CPU
# C:\Users\keval\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# I will remove hdd
# I will remove ddr4
# I will remove resolution_x
# I will remove touchpad
# I will remove screen size
# I will remove camera
# I will remove CPU clock speed (GHz)
# I will remove windows 10 home
# I will remove intel core i7
# I will remove keyboard
# I will remove bluetooth
# I will remove CPU cores
# I will remove resolution_y
#                             feature        VIF
# 0   windows 8.1 professional 32-bit   1.003809
# 1             windows 7 home 64-bit   1.007310
# 2                   intel celeron m   1.014100
# 3     windows 7 professional 32-bit   1.017267
# 4                      intel core m   1.026308
# 5           windows 8.1 home 32-bit   1.027115
# 6                            amd a4   1.031958
# 7                            amd e1   1.033196
# 8                           amd a10   1.040190
# 9                           amd a12   1.058642
# 10                           hybrid   1.067349
# 11             wi-fi 802.11 a/b/g/n   1.067608
# 12                           amd a8   1.073661
# 13  windows 8.1 professional 64-bit   1.078143
# 14         intel celeron quad core    1.097492
# 15         intel pentium quad-core    1.105225
# 16               wi-fi 802.11 b/g/n   1.108316
# 17          wi-fi 802.11 a/b/g/n/ac   1.130758
# 18            wi-fi 802.11 b/g/n/ac   1.138977
# 19                   intel celeron    1.152942
# 20          windows 8.1 home 64-bit   1.229752
# 21                           amd a6   1.233079
# 22          intel celeron dual-core   1.259629
# 23                             emmc   1.273375
# 24    windows 7 professional 64-bit   1.323926
# 25          intel pentium dual-core   1.388364
# 26                            other   1.528748
# 27                            ddr3l   1.548408
# 28                        no system   1.566744
# 29          windows 10 professional   1.737613
# 30                   modem 4g (lte)   1.838992
# 31                        ssd + hdd   2.161087
# 32                              gps   2.165594
# 33                    intel core i5   2.281815
# 34                    intel core i3   2.406999
# 35                             ddr3   2.588843
# 36                            wi-fi   3.621366
# 37             illuminated keyboard   3.724240
# 38                  lan 10/100 mbps   4.080728
# 39                 numeric keyboard   4.368419
# 40                         RAM size   4.464195
# 41                              ssd   4.590356
# 42    intel wireless display (widi)   4.755716
# 43                  modem 3g (wwan)   4.865520
# 44   nfc (near field communication)   6.280559
# 45             lan 10/100/1000 mbps   6.620121
# 46           drive memory size (GB)   7.693896
# 47                   SD card reader  14.561399
# 48                         speakers  15.568505
# 49                       microphone  16.275451

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# correlation matrix of multicollinearity free dataset
plt.figure(figsize=(20, 20)) # width and height in inches
corr_df = pd.concat([new_df[selected_features], df[label_col]], axis=1)
sns.heatmap(corr_df.corr(),annot=True, lw=1)
plt.show()

# %% [markdown]
# ## Train Test Split

# %%
# use the indeces of given datasets to properly separate it again as initial datasets
train_indeces = train_df.dropna().index
val_indeces = val_df.dropna().index
test_indeces = test_df.dropna().index

# %%
train_df = new_df.loc[train_indeces]
val_df = new_df.loc[val_indeces]
test_df = new_df.loc[test_indeces]

# %%
# sklearn machine learning models expect y_train, y_test, y_val 
# in the shape as (row_number, ) instead of (row_number, 1) shape, so apply .ravel()
X_train, X_val, X_test = train_df[selected_features].to_numpy(), val_df[selected_features].to_numpy(), test_df[selected_features].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()

# %%
X_train.shape
y_train.shape
# Out:
# (3694,)

# %% [markdown]
# ## Classical Machine Learning
# I will implement and try different machine learning models from Linear Regression to Ensemble Methods. I have scaled the data with MaxAbsScaler() from sklearn, which works well with sparse datasets.

# %%
import numpy as np
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error 
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import VotingRegressor
from sklearn import linear_model
from sklearn.neural_network import MLPRegressor

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, MaxAbsScaler

import matplotlib.pyplot as plt
from sklearn import tree
import seaborn as sns

def rmse(y_true, y_pred): 
    return mean_squared_error(y_true, y_pred, squared=False)


def regression(regressor_name, regressor):
#     alternative scaler 
#     pipe = make_pipeline(StandardScaler(), regressor)
    pipe = make_pipeline(MaxAbsScaler(), regressor)
    pipe.fit(X_train, y_train) 
    predicted = pipe.predict(X_test)
    rmse_val = rmse(y_test, predicted)
    print(regressor_name, ':', rmse_val)
    pred_df[regressor_name+'_Pred'] = predicted
    plt.figure(regressor_name)
    plt.title(regressor_name)
    plt.xlabel('predicted')
    plt.ylabel('actual')
    sns.regplot(y=y_test,x=predicted)
    
regressors = {
    'Linear' : LinearRegression(),
    'MLP': MLPRegressor(random_state=42, max_iter=500, learning_rate="constant", learning_rate_init=0.6),
    'DecisionTree': DecisionTreeRegressor(max_depth=15, random_state=42),
    'RandomForest': RandomForestRegressor(random_state=42),
    'GradientBoosting': GradientBoostingRegressor(random_state=42, criterion='squared_error',
                                                  loss='squared_error',learning_rate=0.6, warm_start=True),
    'ExtraTrees': ExtraTreesRegressor(n_estimators=100, random_state=42),
}

pred_df = pd.DataFrame(columns =["Actual"])
pred_df["Actual"] = y_test

for key in regressors.keys():
    regression(key, regressors[key])
# Out:
# C:\Users\keval\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Linear : 794.4322090893721
# C:\Users\keval\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# MLP : 929.1737544856878
# C:\Users\keval\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# DecisionTree : 721.8544114428656
# C:\Users\keval\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# RandomForest : 604.2753477464071
# C:\Users\keval\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# GradientBoosting : 595.3663823907888
# C:\Users\keval\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ExtraTrees : 626.8981784469452

# %% [markdown]
# ## Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor

# classifiers
reg1 = regressors["GradientBoosting"]
reg2 = regressors["ExtraTrees"]
reg3 = regressors["RandomForest"]

# take the highest performed three models and combine them in a voting mechanism
# assign weights to their predictions and create new regressor
# it is possible to try with different weights 
regression("Voting", VotingRegressor([("gb", reg1), ("et", reg2), ("rf", reg3)], weights=[0.4, 0.35, 0.25]))
# Out:
# C:\Users\keval\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Voting : 543.2265486185663

# %%
pred_df
# Out:
#        Actual  Linear_Pred     MLP_Pred  DecisionTree_Pred  RandomForest_Pred  \
# 0     2369.00  2373.597020  2292.609221        2222.333333        2222.893810
# 1     2299.00  2454.518684  2392.399630        2484.815789        2371.896667
# 2     5999.00  5071.691823  5040.808447        4965.666667        4996.982143
# 3     1299.00  1023.199263  1297.628429        1249.000000        1250.719246
# 4     3329.00  6673.546897  5779.298653        6949.000000        6663.369444
# ...       ...          ...          ...                ...                ...
# 1195  5599.00  5775.362437  5494.984232        5674.000000        5679.553571
# 1196  2925.36  3085.104468  2526.242418        2591.813200        2701.029150
# 1197  3799.00  4241.897667  4128.341788        4561.500000        4321.287000
# 1198  5589.00  5120.472392  4939.428678        4872.000000        4776.211333
# 1199  8678.00  8046.627665  8152.769963        8349.000000        7939.960000
#
#       GradientBoosting_Pred  ExtraTrees_Pred  Voting_Pred
# 0               2420.643428      2222.333333  2301.797490
# 1               2220.247044      2384.000000  2315.472984
# 2               5093.636196      4999.000000  5036.350014
# 3               1224.296853      1249.000000  1239.548553
# 4               4814.473279      6442.750000  5846.594173
# ...                     ...              ...          ...
# 1195            6188.638075      5674.000000  5881.243623
# 1196            2597.663560      2693.507500  2657.050336
# 1197            4016.085136      4195.530000  4155.191304
# 1198            5195.381640      4312.935000  4781.732739
# 1199            8108.833334      8214.350000  8103.545834
#
# [1200 rows x 8 columns]

# %% [markdown]
# It improves the performance of the RandomForest. We can go ahead with this voting model as our official solution.

# %% [markdown]
# ## Feature Selection
# Feature selection hurts the performance of this task. However, it is always best to present all the methods applied through the assignment. Hence, we are representing it also. We used f_regression and RandomForestRegressor.modelimportances to check feature importance. We decided on k=15, but you can change and see the results for different k values

# %%
from sklearn.feature_selection import SelectKBest, f_regression
#Select top 25 features based on f-regression
selector = SelectKBest(f_regression, k =25)
X = new_df[selected_features].to_numpy()
y = df[label_col].to_numpy().ravel()
selector.fit(X, y)
cols = new_df[selected_features].columns[selector.get_support()].to_list()
cols
# Out:
# ['intel pentium quad-core ',
#  'intel celeron ',
#  'windows 8.1 home 64-bit',
#  'amd a6',
#  'intel celeron dual-core',
#  'emmc',
#  'intel pentium dual-core',
#  'other',
#  'ddr3l',
#  'no system',
#  'windows 10 professional',
#  'modem 4g (lte)',
#  'ssd + hdd',
#  'intel core i3',
#  'ddr3',
#  'wi-fi',
#  'illuminated keyboard',
#  'lan 10/100 mbps',
#  'numeric keyboard',
#  'RAM size',
#  'intel wireless display (widi)',
#  'modem 3g (wwan)',
#  'nfc (near field communication)',
#  'drive memory size (GB)',
#  'SD card reader']

# %%
X_train, X_val, X_test = train_df[cols].to_numpy(), val_df[cols].to_numpy(), test_df[cols].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()

# %%
regression('RandomForest', regressors['RandomForest'])
# Out:
# C:\Users\keval\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# RandomForest : 736.9071175455939

# %%
X = new_df[selected_features].values
X_train, X_val, X_test = train_df[selected_features].to_numpy(), val_df[selected_features].to_numpy(), test_df[selected_features].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()
model = RandomForestRegressor(random_state=42)
# fit the model
model.fit(X_train, y_train)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print(f"Feature: {selected_features[i]} , Score: {v}")
# plot feature importance
plt.figure(figsize=(12, 9)) # width and height in inches
plt.bar(selected_features, importance)
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()
# Out:
# Feature: windows 8.1 professional 32-bit , Score: 4.810689624538485e-06
# Feature: windows 7 home 64-bit , Score: 0.0
# Feature: intel celeron m , Score: 7.3554278709924e-05
# Feature: windows 7 professional 32-bit , Score: 0.0
# Feature: intel core m , Score: 0.0002266984700607659
# Feature: windows 8.1 home 32-bit , Score: 8.600625225448644e-05
# Feature: amd a4 , Score: 0.00045751140898403226
# Feature: amd e1 , Score: 0.0002670158662038192
# Feature: amd a10 , Score: 0.0006366782404907569
# Feature: amd a12 , Score: 0.00023839630878936258
# Feature: hybrid , Score: 0.0004379279547672437
# Feature: wi-fi 802.11 a/b/g/n , Score: 0.00037786906716814986
# Feature: amd a8 , Score: 0.0003626115253238574
# Feature: windows 8.1 professional 64-bit , Score: 0.0006198258529816793
# Feature: intel celeron quad core  , Score: 0.00014862929923655828
# Feature: intel pentium quad-core  , Score: 0.0007590677752839065
# Feature: wi-fi 802.11 b/g/n , Score: 0.0003618387431345358
# Feature: wi-fi 802.11 a/b/g/n/ac , Score: 0.0013913043430696947
# Feature: wi-fi 802.11 b/g/n/ac , Score: 0.0006405118913359903
# Feature: intel celeron  , Score: 0.0004815375907977889
# Feature: windows 8.1 home 64-bit , Score: 0.0010849679208070103
# Feature: amd a6 , Score: 0.0028152186619363317
# Feature: intel celeron dual-core , Score: 0.001799805631315259
# Feature: emmc , Score: 5.9301815143748575e-05
# Feature: windows 7 professional 64-bit , Score: 0.001588504897648521
# Feature: intel pentium dual-core , Score: 0.0013072499514547474
# Feature: other , Score: 0.004105070922731269
# Feature: ddr3l , Score: 0.006417779171409947
# Feature: no system , Score: 0.020767244426574048
# Feature: windows 10 professional , Score: 0.030748450246545687
# Feature: modem 4g (lte) , Score: 0.005264655414849057
# Feature: ssd + hdd , Score: 0.004165494019411714
# Feature: gps , Score: 0.0025631665254878078
# Feature: intel core i5 , Score: 0.034276719102856554
# Feature: intel core i3 , Score: 0.01711346108478545
# Feature: ddr3 , Score: 0.025732171579442242
# Feature: wi-fi , Score: 0.011952777168380592
# Feature: illuminated keyboard , Score: 0.417824781394016
# Feature: lan 10/100 mbps , Score: 0.02531278505294521
# Feature: numeric keyboard , Score: 0.022328606139788612
# Feature: RAM size , Score: 0.11051811519972406
# Feature: ssd , Score: 0.01681845162491978
# Feature: intel wireless display (widi) , Score: 0.00916571746870353
# Feature: modem 3g (wwan) , Score: 0.004881644284383514
# Feature: nfc (near field communication) , Score: 0.004411005099408878
# Feature: lan 10/100/1000 mbps , Score: 0.009603874452862558
# Feature: drive memory size (GB) , Score: 0.07035469675251318
# Feature: SD card reader , Score: 0.12071096923748684
# Feature: speakers , Score: 0.0022021907942647383
# Feature: microphone , Score: 0.006533328399986

# %%
feats_w_highest_importance = np.array(selected_features)[importance > 0.02].tolist()
feats_w_highest_importance
# Out:
# ['no system',
#  'windows 10 professional',
#  'intel core i5',
#  'ddr3',
#  'illuminated keyboard',
#  'lan 10/100 mbps',
#  'numeric keyboard',
#  'RAM size',
#  'drive memory size (GB)',
#  'SD card reader']

# %%
X_train, X_val, X_test = train_df[feats_w_highest_importance].to_numpy(), val_df[feats_w_highest_importance].to_numpy(), test_df[feats_w_highest_importance].to_numpy()
y_train, y_val, y_test = df.loc[train_indeces][label_col].to_numpy().ravel(), df.loc[val_indeces][label_col].to_numpy().ravel(), df.loc[test_indeces][label_col].to_numpy().ravel()

# %%
regression('RandomForest', regressors['RandomForest'])
# Out:
# C:\Users\keval\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# RandomForest : 715.6595361720808

# %% [markdown]
# Still, the complete feature set provides better results compared to features with the highest importance.

# %% [markdown]
# # Voting Regrressor takes the cake as the best model in this case !!!

# %% [markdown]
# ## This was my personal weekend project, I would love to hear if you have any feedback regarding best practices or how to make this project better. You can check out my other projects as well !!!
